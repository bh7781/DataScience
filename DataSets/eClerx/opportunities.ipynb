# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
opportunities_original = pd.read_csv('Opportunity.csv', encoding = 'unicode_escape')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (2,18,21,23,24,25,52,79,96,104,106,126,132,134,138,139,141,149,152,153,154,155,156,157,159,160,161,163) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
opportunities = opportunities_original.copy()

# %%
opportunities.head()
# Out:
#   Account_Development_Rep__c           AccountId Americas_Partner_Select__c  \
# 0                      Rep 1  0011600001l4gN3AAI                        NaN
# 1                      Rep 1  001G000001AwRnrIAF                        NaN
# 2                      Rep 2  0011600001l52ZIAAY                        NaN
# 3                        NaN  001A000000BdFfbIAF                        NaN
# 4                      Rep 3  001G000001kpDrdIAE                        NaN
#
#     Amount  Amount_Billed_To_Date__c  Approved_Discount__c  Audit_Flag__c  \
# 0  50000.0                         0                     0            NaN
# 1  50000.0                         0                     0            NaN
# 2  25000.0                         0                     0            NaN
# 3  51500.0                         0                     0            NaN
# 4  50000.0                         0                     0            NaN
#
#   Bill_To_Customer__c Business_Issues__c          CampaignId  \
# 0                 NaN        Not Started  701G0000000yx3VIAQ
# 1                 NaN        Not Started  701G0000000yx3VIAQ
# 2                 NaN        Not Started  70116000000z0icAAA
# 3                 NaN        Not Started                 NaN
# 4                 NaN        Not Started                 NaN
#
#            ...            Total_Spigit_Subscriptions_old__c  \
# 0          ...                                      25000.0
# 1          ...                                      25000.0
# 2          ...                                          NaN
# 3          ...                                          NaN
# 4          ...                                          NaN
#
#    Total_Subscriptions__c  TotalOpportunityQuantity             Type  \
# 0                       1                       2.0            Pilot
# 1                       1                       2.0            Pilot
# 2                       1                       1.0     New Business
# 3                       0                       1.0  Upsell Business
# 4                       1                       2.0            Pilot
#
#    Upgrade_Opportunity__c Vendor_Set_up_Complete__c  \
# 0             Not Upgrade                       NaN
# 1             Not Upgrade                       NaN
# 2             Not Upgrade                       NaN
# 3             Not Upgrade                       NaN
# 4             Not Upgrade                       NaN
#
#                                What_Happened_Last__c  \
# 0                                        Not Started
# 1                                        Not Started
# 2                                        Not Started
# 3  2/20 SOW finalized and verbiage agreed to.  No...
# 4           face to face meeting in Bracknell in Feb
#
#                                 What_Happens_Next__c What_is_major_risk__c  \
# 0                                                NaN           Not Started
# 1                                                NaN           Not Started
# 2                                                NaN           Not Started
# 3  Get SOW countersigned, and get PO from SoCo--e...           Not Started
# 4                                                NaN           Not Started
#
#   Who_signs_contracts__c
# 0            Not Started
# 1            Not Started
# 2            Not Started
# 3            Not Started
# 4            Not Started
#
# [5 rows x 185 columns]

# %%
print(opportunities.info())
print(opportunities.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4181 entries, 0 to 4180
# Columns: 185 entries, Account_Development_Rep__c to Who_signs_contracts__c
# dtypes: bool(12), float64(70), int64(12), object(91)
# memory usage: 5.6+ MB
# None
# (4181, 185)

# %%
opportunities.describe()
# Out:
#              Amount  Amount_Billed_To_Date__c  Approved_Discount__c  \
# count  3.431000e+03              4.181000e+03                4181.0
# mean   7.756175e+04              1.197833e+03                   0.0
# std    1.150384e+05              3.374742e+04                   0.0
# min   -1.585270e+05              0.000000e+00                   0.0
# 25%    2.500000e+04              0.000000e+00                   0.0
# 50%    5.000000e+04              0.000000e+00                   0.0
# 75%    8.500000e+04              0.000000e+00                   0.0
# max    2.500000e+06              2.021100e+06                   0.0
#
#        Audit_Flag__c  CDR__c  CDT_Next_Step__c  CDT_Next_Step_Due_Date__c  \
# count            0.0     0.0               0.0                        0.0
# mean             NaN     NaN               NaN                        NaN
# std              NaN     NaN               NaN                        NaN
# min              NaN     NaN               NaN                        NaN
# 25%              NaN     NaN               NaN                        NaN
# 50%              NaN     NaN               NaN                        NaN
# 75%              NaN     NaN               NaN                        NaN
# max              NaN     NaN               NaN                        NaN
#
#        CDT_Status__c  Credit_Card_CVV__c  Dataset_ID__c  \
# count            0.0                 0.0            0.0
# mean             NaN                 NaN            NaN
# std              NaN                 NaN            NaN
# min              NaN                 NaN            NaN
# 25%              NaN                 NaN            NaN
# 50%              NaN                 NaN            NaN
# 75%              NaN                 NaN            NaN
# max              NaN                 NaN            NaN
#
#                  ...             Total_Connect_Seats__c  \
# count            ...                        4181.000000
# mean             ...                           0.000239
# std              ...                           0.015465
# min              ...                           0.000000
# 25%              ...                           0.000000
# 50%              ...                           0.000000
# 75%              ...                           0.000000
# max              ...                           1.000000
#
#        Total_Customer_Stories__c  Total_MindManager_Seats__c  Total_MSAs__c  \
# count                4181.000000                 4181.000000    4181.000000
# mean                    0.000239                    0.000239       0.004305
# std                     0.015465                    0.026789       0.075651
# min                     0.000000                   -1.000000       0.000000
# 25%                     0.000000                    0.000000       0.000000
# 50%                     0.000000                    0.000000       0.000000
# 75%                     0.000000                    0.000000       0.000000
# max                     1.000000                    1.000000       2.000000
#
#        Total_Spigit_Consulting__c  Total_Spigit_Consulting_old__c  \
# count                4.181000e+03                    4.096000e+03
# mean                 1.315622e+04                    1.307207e+04
# std                  5.960927e+04                    6.025119e+04
# min                 -2.500000e+04                   -2.500000e+04
# 25%                  0.000000e+00                    0.000000e+00
# 50%                  0.000000e+00                    0.000000e+00
# 75%                  1.046000e+04                    1.000000e+04
# max                  2.500000e+06                    2.500000e+06
#
#        Total_Spigit_Subscriptions__c  Total_Spigit_Subscriptions_old__c  \
# count                    4181.000000                       4.096000e+03
# mean                    15336.683872                       5.083470e+04
# std                     39295.569178                       8.963283e+04
# min                   -158527.000000                      -1.585270e+05
# 25%                         0.000000                       0.000000e+00
# 50%                         0.000000                       2.500000e+04
# 75%                      3900.000000                       6.000000e+04
# max                    795000.000000                       2.000000e+06
#
#        Total_Subscriptions__c  TotalOpportunityQuantity
# count             4181.000000               3429.000000
# mean                15.715618                 21.914990
# std                807.258956                895.432064
# min                 -2.000000                 -2.000000
# 25%                  0.000000                  1.000000
# 50%                  0.000000                  1.000000
# 75%                  0.000000                  2.000000
# max              50000.000000              50001.000000
#
# [8 rows x 82 columns]

# %%
opportunities = opportunities[opportunities.IsClosed == True]
opportunities.IsClosed.head()
# Out:
# 1     True
# 3     True
# 7     True
# 15    True
# 19    True
# Name: IsClosed, dtype: bool

# %%
opportunities.IsClosed.tail()
# Out:
# 4137    True
# 4142    True
# 4145    True
# 4153    True
# 4169    True
# Name: IsClosed, dtype: bool

# %%
opportunities.shape
# Out:
# (3374, 185)

# %%
opportunities.columns.get_loc('IsWon')
# Out:
# 64

# %%
X = opportunities.loc[:, opportunities.columns != 'IsWon']

# %%
y = opportunities['IsWon']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
rf = RandomForestClassifier(n_estimators=10000, random_state=0)

# %%
rf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-168a6fc83696> in <module>()
# ----> 1 rf.fit(X_train, y_train)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     245         """
#     246         # Validate or convert input data
# --> 247         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     248         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     249         if sample_weight is not None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# --> 433         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     434
#     435         if ensure_2d:
#
# ValueError: could not convert string to float: 'Not Started'

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier(random_state=0)
dtree.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-15df6b35a14b> in <module>()
#       1 from sklearn.tree import DecisionTreeClassifier
#       2 dtree = DecisionTreeClassifier(random_state=0)
# ----> 3 dtree.fit(X_train, y_train)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     788             sample_weight=sample_weight,
#     789             check_input=check_input,
# --> 790             X_idx_sorted=X_idx_sorted)
#     791         return self
#     792
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     114         random_state = check_random_state(self.random_state)
#     115         if check_input:
# --> 116             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     117             y = check_array(y, ensure_2d=False, dtype=None)
#     118             if issparse(X):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# --> 433         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     434
#     435         if ensure_2d:
#
# ValueError: could not convert string to float: 'Not Started'
