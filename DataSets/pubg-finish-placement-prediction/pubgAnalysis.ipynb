# %%
import pandas as pd

# %%
pubg_original = pd.read_csv('C:\\Users\\chinmay.shelke\\OneDrive - Accenture\\Data Science\\GitHub Repositories\\MyWorkspace\\Other Datasets\\PUBG_FinishPlacementPrediction\\train_V2.csv')

# %%
pubg_df = pubg_original.copy()

# %%
pubg_df.head(15)
# Out:
#                 Id         groupId         matchId  assists  boosts  \
# 0   7f96b2f878858a  4d4b580de459be  a10357fd1a4a91        0       0
# 1   eef90569b9d03c  684d5656442f9e  aeb375fc57110c        0       0
# 2   1eaf90ac73de72  6a4a42c3245a74  110163d8bb94ae        1       0
# 3   4616d365dd2853  a930a9c79cd721  f1f1f4ef412d7e        0       0
# 4   315c96c26c9aac  de04010b3458dd  6dc8ff871e21e6        0       0
# 5   ff79c12f326506  289a6836a88d27  bac52627a12114        0       0
# 6   95959be0e21ca3  2c485a1ad3d0f1  a8274e903927a2        0       0
# 7   311b84c6ff4390  eaba5fcb7fc1ae  292611730ca862        0       0
# 8   1a68204ccf9891  47cfbb04e1b1a2  df014fbee741c6        0       0
# 9   e5bb5a43587253  759bb6f7514fd2  3d3031c795305b        0       0
# 10  2b574d43972813  c549efede67ad3  2dd6ddb8320fc1        0       0
# 11  8de328a74658a9  f643df9df3877c  80170383d90003        0       0
# 12  ce4f6ac165705e  da24cdb91969cc  535b5dbd965a94        0       0
# 13  b7807186e3f679  3c08e461874749  2c30ddf481c52d        0       1
# 14  8e244ac61b6aab  d40d0c7d3573a1  94e1c1cc443c65        0       1
#
#     damageDealt  DBNOs  headshotKills  heals  killPlace      ...       \
# 0         0.000      0              0      0         60      ...
# 1        91.470      0              0      0         57      ...
# 2        68.000      0              0      0         47      ...
# 3        32.900      0              0      0         75      ...
# 4       100.000      0              0      0         45      ...
# 5       100.000      1              1      0         44      ...
# 6         0.000      0              0      0         96      ...
# 7         8.538      0              0      0         48      ...
# 8        51.600      0              0      0         64      ...
# 9        37.270      0              0      0         74      ...
# 10       28.380      0              0      0         75      ...
# 11      137.900      1              0      0         64      ...
# 12        0.000      0              0      0         37      ...
# 13      324.200      0              1      5          5      ...
# 14      122.800      1              0      2         25      ...
#
#     revives  rideDistance  roadKills  swimDistance  teamKills vehicleDestroys  \
# 0         0        0.0000          0          0.00          0               0
# 1         0        0.0045          0         11.04          0               0
# 2         0        0.0000          0          0.00          0               0
# 3         0        0.0000          0          0.00          0               0
# 4         0        0.0000          0          0.00          0               0
# 5         0        0.0000          0          0.00          0               0
# 6         0        0.0000          0          0.00          0               0
# 7         0     2004.0000          0          0.00          0               0
# 8         0        0.0000          0          0.00          0               0
# 9         0        0.0000          0          0.00          0               0
# 10        0        0.0000          0          0.00          0               0
# 11        0        0.0000          0          0.00          0               0
# 12        0     6639.0000          0          0.00          0               0
# 13        0     1228.0000          0         76.84          0               0
# 14        1     1237.0000          0         60.29          0               0
#
#     walkDistance  weaponsAcquired  winPoints  winPlacePerc
# 0         244.80                1       1466        0.4444
# 1        1434.00                5          0        0.6400
# 2         161.80                2          0        0.7755
# 3         202.70                3          0        0.1667
# 4          49.75                2          0        0.1875
# 5          34.70                1          0        0.0370
# 6          13.50                1       1497        0.0000
# 7        1089.00                6       1500        0.7368
# 8         799.90                4          0        0.3704
# 9          65.67                1          0        0.2143
# 10        868.30                9          0        0.3929
# 11        451.70                1          0        0.4043
# 12       2784.00                6          0        0.9286
# 13       2050.00                6       1462        0.8750
# 14       1666.00                5       1531        0.9000
#
# [15 rows x 29 columns]

# %%
pubg_df.columns
# Out:
# Index(['Id', 'groupId', 'matchId', 'assists', 'boosts', 'damageDealt', 'DBNOs',
#        'headshotKills', 'heals', 'killPlace', 'killPoints', 'kills',
#        'killStreaks', 'longestKill', 'matchDuration', 'matchType', 'maxPlace',
#        'numGroups', 'rankPoints', 'revives', 'rideDistance', 'roadKills',
#        'swimDistance', 'teamKills', 'vehicleDestroys', 'walkDistance',
#        'weaponsAcquired', 'winPoints', 'winPlacePerc'],
#       dtype='object')

# %%
pubg_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4446966 entries, 0 to 4446965
# Data columns (total 29 columns):
# Id                 object
# groupId            object
# matchId            object
# assists            int64
# boosts             int64
# damageDealt        float64
# DBNOs              int64
# headshotKills      int64
# heals              int64
# killPlace          int64
# killPoints         int64
# kills              int64
# killStreaks        int64
# longestKill        float64
# matchDuration      int64
# matchType          object
# maxPlace           int64
# numGroups          int64
# rankPoints         int64
# revives            int64
# rideDistance       float64
# roadKills          int64
# swimDistance       float64
# teamKills          int64
# vehicleDestroys    int64
# walkDistance       float64
# weaponsAcquired    int64
# winPoints          int64
# winPlacePerc       float64
# dtypes: float64(6), int64(19), object(4)
# memory usage: 983.9+ MB

# %%
pubg_df.describe('O')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-ad9562be4297> in <module>()
# ----> 1 pubg_df.describe('O')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in describe(self, percentiles, include, exclude)
#    8499
#    8500             # get them all to be in [0, 1]
# -> 8501             self._check_percentile(percentiles)
#    8502
#    8503             # median should always be included
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in _check_percentile(self, q)
#    8591                 raise ValueError(msg.format(q / 100.0))
#    8592         else:
# -> 8593             if not all(0 <= qs <= 1 for qs in q):
#    8594                 raise ValueError(msg.format(q / 100.0))
#    8595         return q
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in <genexpr>(.0)
#    8591                 raise ValueError(msg.format(q / 100.0))
#    8592         else:
# -> 8593             if not all(0 <= qs <= 1 for qs in q):
#    8594                 raise ValueError(msg.format(q / 100.0))
#    8595         return q
#
# TypeError: '<=' not supported between instances of 'int' and 'numpy.str_'
